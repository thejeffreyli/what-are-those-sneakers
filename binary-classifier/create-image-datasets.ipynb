# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# training/testing dataset
from sklearn.model_selection import train_test_split

# google colab
from google.colab import drive

# import cv2

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Sneakers-Classifier-App/
# Out:
# /content/drive/MyDrive/Sneakers-Classifier-App

# %% [markdown]
# Quality Check: Please manually go through each directory and ensure the sneakers in the images match the directory SKU.

# %%
# TODO: initialize paths
source_path = "unclean/"
save_path = "clean/data/"

# %%
sneaker_img_list = [] # store image names
sneaker_label_list = [] # store label; 0/1

# target_size = (100, 100)

# inventory purposes
count_aj1 = 0
count_yzy = 0

# %%
# iterate through all files
file_list = os.listdir(source_path)
for file_name in file_list:

    # link to new dir
    path = source_path + file_name + "/"

    # iterate through all images in dir
    for i in os.listdir(path):

        source_img = path + i
        img = plt.imread(source_img)
        # img = cv2.resize(img, target_size, interpolation=cv2.INTER_AREA) # resize
        img = Image.fromarray(img)

        if "DZ5485-612" in path: # AJ1
            count_aj1 += 1

            img_name = "DZ5485-612-" + str(count_aj1) + ".jpg"
            sneaker_img_list.append(img_name)
            sneaker_label_list.append(1)
            img.save(save_path + img_name)

        else: # CP9652, Yeezy
            count_yzy += 1

            img_name = "CP9652-" + str(count_yzy) + ".jpg"
            sneaker_img_list.append(img_name)
            sneaker_label_list.append(0)
            img.save(save_path + img_name)

# %%
X = sneaker_img_list
y = sneaker_label_list

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# create dataframes
train_df = pd.DataFrame({"Image": X_train, "Label": y_train})
test_df = pd.DataFrame({"Image": X_test, "Label": y_test})

# %%
# save dataframes
train_df.to_csv("train_dataset.csv", index=False)
test_df.to_csv("test_dataset.csv", index=False)
